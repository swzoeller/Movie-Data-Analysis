# %% [markdown]
# # Data Merging and Cleaning

# %% [markdown]
# ### Getting Started

# %% [markdown]
# Importing needed libraries and reading already gathered csv data.

# %%
import pandas as pd
from config import tmdb_api_key
import requests

# %%
numbers_budget_df = pd.read_csv('Data/tn.movie_budgets.csv')
tmdb_df = pd.read_csv('Data/tmdb_df.csv')

# %%
print(numbers_budget_df.shape)
print(tmdb_df.shape)
# Out:
# (5782, 6)
# (4776, 14)

# %%
print(numbers_budget_df.columns)
print(tmdb_df.columns)
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')
# Index(['popularity', 'vote_count', 'video', 'poster_path', 'id', 'adult',
#        'backdrop_path', 'original_language', 'original_title', 'genre_ids',
#        'title', 'vote_average', 'overview', 'release_date'],
#       dtype='object')

# %% [markdown]
# ### Data Merging

# %% [markdown]
# We will merge on the title and year values simultaneously, as multiple movies have the same titles. We need to create these indicies to be merged on.

# %%
numbers_budget_df.rename(columns={'movie':'title'}, inplace=True)
numbers_budget_df['year'] = numbers_budget_df['release_date'].map(lambda x: str(x)[-4:])
tmdb_df['year'] = tmdb_df['release_date'].map(lambda x: str(x)[:4])

# %%
merged_df = numbers_budget_df.merge(tmdb_df, on=['title', 'year'], how='inner')
merged_df
# Out:
#       id_x release_date_x                                        title  \
# 0        1   Dec 18, 2009                                       Avatar
# 1        2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2        3    Jun 7, 2019                                 Dark Phoenix
# 3        4    May 1, 2015                      Avengers: Age of Ultron
# 4        7   Apr 27, 2018                       Avengers: Infinity War
# ...    ...            ...                                          ...
# 4361    65   Dec 31, 2007                                  Tin Can Man
# 4362    67   Apr 28, 2006                                        Clean
# 4363    71   Aug 14, 2008              The Rise and Fall of Miss Thang
# 4364    75    Oct 8, 2004                                       Primer
# 4365    79    Apr 2, 1999                                    Following
#
#      production_budget domestic_gross worldwide_gross  year  popularity  \
# 0         $425,000,000   $760,507,625  $2,776,345,279  2009      81.649
# 1         $410,600,000   $241,063,875  $1,045,663,875  2011      49.185
# 2         $350,000,000    $42,762,350    $149,762,350  2019     122.894
# 3         $330,600,000   $459,005,868  $1,403,013,963  2015      77.916
# 4         $300,000,000   $678,815,482  $2,048,134,200  2018     240.150
# ...                ...            ...             ...   ...         ...
# 4361           $12,000             $0              $0  2007       1.584
# 4362           $10,000       $138,711        $138,711  2006       0.600
# 4363           $10,000           $401            $401  2008       0.600
# 4364            $7,000       $424,760        $841,926  2004      71.750
# 4365            $6,000        $48,482        $240,495  1999       8.174
#
#       vote_count  video                       poster_path    id_y  adult  \
# 0          22183  False  /6EiRUJpuoeQPghrs3YNktfnqOVh.jpg   19995  False
# 1          10310  False  /9zxsSzXx2UO3yNoS4j97vs4uOhc.jpg    1865  False
# 2           3997  False  /cCTJPelKGLhALq3r51A9uMonxKj.jpg  320288  False
# 3          16653  False  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg   99861  False
# 4          19926  False  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  299536  False
# ...          ...    ...                               ...     ...    ...
# 4361           3  False  /2YMMRWzq9SzZEYau1iAtdTPN269.jpg  157185  False
# 4362           0  False  /kOk47vD8E0dScAyNVNCXhsncaE4.jpg  586483  False
# 4363           0  False  /2YkIO5qjfhyICn5wXhLYMJLk152.jpg  579116  False
# 4364        1378  False  /xEoq2WmDzpzxhkHEsmOYOg6BPg6.jpg   14337  False
# 4365         934  False  /lK9LE5D67HNyPlhJcjKAgnRh0OO.jpg   11660  False
#
#                          backdrop_path original_language  \
# 0     /bIL7ENqh1egWTxN41sM2W42JqPc.jpg                en
# 1     /bfTKq6mGHt2CzZlBU31JHF9bMog.jpg                en
# 2     /phxiKFDvPeQj4AbkvJLmuZEieDU.jpg                en
# 3     /8i6ZDk97Vyh0jHohMG4vFeFuKJh.jpg                en
# 4     /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg                en
# ...                                ...               ...
# 4361                               NaN                en
# 4362                               NaN                en
# 4363                               NaN                en
# 4364  /gIFbfh9O4HBrO6numxVBxtZ9fTL.jpg                en
# 4365  /gCpl06aiAGUrPrmspeqhdKVQRT1.jpg                en
#
#                                    original_title          genre_ids  \
# 0                                          Avatar  [28, 12, 14, 878]
# 1     Pirates of the Caribbean: On Stranger Tides       [28, 12, 14]
# 2                                    Dark Phoenix      [28, 12, 878]
# 3                         Avengers: Age of Ultron      [28, 12, 878]
# 4                          Avengers: Infinity War      [28, 12, 878]
# ...                                           ...                ...
# 4361                                  Tin Can Man               [27]
# 4362                                        Clean                 []
# 4363              The Rise and Fall of Miss Thang                 []
# 4364                                       Primer      [18, 878, 53]
# 4365                                    Following           [18, 53]
#
#       vote_average                                           overview  \
# 0              7.5  In the 22nd century, a paraplegic Marine is di...
# 1              6.5  Captain Jack Sparrow crosses paths with a woma...
# 2              6.1  The X-Men face their most formidable and power...
# 3              7.3  When Tony Stark tries to jumpstart a dormant p...
# 4              8.3  As the Avengers and their allies have continue...
# ...            ...                                                ...
# 4361           3.0  Recently dumped by his girlfirend for another ...
# 4362           0.0  A dangerous serial killer decides to go out wi...
# 4363           0.0  An irresponsible party girl begins a journey t...
# 4364           6.9  Friends and fledgling entrepreneurs invent a d...
# 4365           7.2  Bill, an idle, unemployed aspiring writer, wal...
#
#      release_date_y
# 0        2009-12-10
# 1        2011-05-14
# 2        2019-06-05
# 3        2015-04-22
# 4        2018-04-25
# ...             ...
# 4361     2007-01-01
# 4362     2006-03-05
# 4363     2008-08-14
# 4364     2004-10-08
# 4365     1999-04-02
#
# [4366 rows x 20 columns]

# %% [markdown]
# In order to analyze genre data, we will break out the genres into a column for each genre, and assign each value a boolean. TMDB has an api function to get all the genre name-to-id relationships, which we will convert into a Python dictionary.

# %%
tmdb_genres = requests.get(f'https://api.themoviedb.org/3/genre/movie/list?api_key={tmdb_api_key}&language=en-US').json()['genres']
tmdb_genres
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 37, 'name': 'Western'}]

# %%
genres = {}
for genre in tmdb_genres:
    genres[str(genre['id'])] = genre['name']
genres
# Out:
# {'28': 'Action',
#  '12': 'Adventure',
#  '16': 'Animation',
#  '35': 'Comedy',
#  '80': 'Crime',
#  '99': 'Documentary',
#  '18': 'Drama',
#  '10751': 'Family',
#  '14': 'Fantasy',
#  '36': 'History',
#  '27': 'Horror',
#  '10402': 'Music',
#  '9648': 'Mystery',
#  '10749': 'Romance',
#  '878': 'Science Fiction',
#  '10770': 'TV Movie',
#  '53': 'Thriller',
#  '10752': 'War',
#  '37': 'Western'}

# %% [markdown]
# Each genre will be looped over, creating a new column in the dataframe. Each column is mapped from the 'genre_ids' column.

# %%
merged_df.genre_ids
# Out:
# 0       [28, 12, 14, 878]
# 1            [28, 12, 14]
# 2           [28, 12, 878]
# 3           [28, 12, 878]
# 4           [28, 12, 878]
#               ...
# 4361                 [27]
# 4362                   []
# 4363                   []
# 4364        [18, 878, 53]
# 4365             [18, 53]
# Name: genre_ids, Length: 4366, dtype: object

# %%
for key, value in genres.items():
    merged_df[value.lower().replace(' ', '_')] = merged_df['genre_ids'].map(lambda x: key in x)

# %%
print(merged_df.shape)
print(merged_df.columns)
# Out:
# (4366, 39)
# Index(['id_x', 'release_date_x', 'title', 'production_budget',
#        'domestic_gross', 'worldwide_gross', 'year', 'popularity', 'vote_count',
#        'video', 'poster_path', 'id_y', 'adult', 'backdrop_path',
#        'original_language', 'original_title', 'genre_ids', 'vote_average',
#        'overview', 'release_date_y', 'action', 'adventure', 'animation',
#        'comedy', 'crime', 'documentary', 'drama', 'family', 'fantasy',
#        'history', 'horror', 'music', 'mystery', 'romance', 'science_fiction',
#        'tv_movie', 'thriller', 'war', 'western'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Movies that have no genre or revene data will not be useful in our analysis, so we will remove them. Dupliactes will also be removed. This only affects 205 data points.

# %%
no_genres = list(merged_df[merged_df['genre_ids'] == '[]'].index)
len(no_genres)
# Out:
# 20

# %%
merged_df.drop(index=no_genres, inplace=True)

# %%
no_gross = list(merged_df[merged_df['worldwide_gross'] == '$0'].index)
len(no_gross)
# Out:
# 180

# %%
merged_df.drop(index=no_gross, inplace=True)

# %%
duplicates = list(merged_df[merged_df.duplicated()].index)
len(duplicates)
# Out:
# 5

# %%
merged_df.drop(index=duplicates, inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4161 entries, 0 to 4365
# Data columns (total 39 columns):
# id_x                 4161 non-null int64
# release_date_x       4161 non-null object
# title                4161 non-null object
# production_budget    4161 non-null object
# domestic_gross       4161 non-null object
# worldwide_gross      4161 non-null object
# year                 4161 non-null object
# popularity           4161 non-null float64
# vote_count           4161 non-null int64
# video                4161 non-null bool
# poster_path          4145 non-null object
# id_y                 4161 non-null int64
# adult                4161 non-null bool
# backdrop_path        3979 non-null object
# original_language    4161 non-null object
# original_title       4161 non-null object
# genre_ids            4161 non-null object
# vote_average         4161 non-null float64
# overview             4161 non-null object
# release_date_y       4161 non-null object
# action               4161 non-null bool
# adventure            4161 non-null bool
# animation            4161 non-null bool
# comedy               4161 non-null bool
# crime                4161 non-null bool
# documentary          4161 non-null bool
# drama                4161 non-null bool
# family               4161 non-null bool
# fantasy              4161 non-null bool
# history              4161 non-null bool
# horror               4161 non-null bool
# music                4161 non-null bool
# mystery              4161 non-null bool
# romance              4161 non-null bool
# science_fiction      4161 non-null bool
# tv_movie             4161 non-null bool
# thriller             4161 non-null bool
# war                  4161 non-null bool
# western              4161 non-null bool
# dtypes: bool(21), float64(2), int64(3), object(13)
# memory usage: 703.0+ KB

# %% [markdown]
# Many of the columns are unecessary, and some have unhelpful data types. We will also create a few new columns from the existing that may be useful, and rename ones with unhelpful titles.

# %%
merged_df.drop(columns = ['id_x', 'release_date_x', 'id_y', 'poster_path', 'adult', 'backdrop_path', 'video'], inplace=True)

# %%
merged_df['production_budget'] = merged_df['production_budget'].map(lambda x: int(str(x).strip('$').replace(',', '')))
merged_df['domestic_gross'] = merged_df['domestic_gross'].map(lambda x: int(str(x).strip('$').replace(',', '')))
merged_df['worldwide_gross'] = merged_df['worldwide_gross'].map(lambda x: int(str(x).strip('$').replace(',', '')))

# %%
merged_df['worldwide_profit(loss)'] = merged_df['worldwide_gross'] - merged_df['production_budget']

# %%
merged_df['roi'] = merged_df['worldwide_profit(loss)'] * 100 / merged_df['production_budget']

# %%
merged_df['year'] = merged_df['year'].map(int)
merged_df['month'] = merged_df['release_date_y'].map(lambda x: int(x.split('-')[1]))
merged_df['day'] = merged_df['release_date_y'].map(lambda x: int(x.split('-')[2]))

# %%
merged_df.rename(columns = {'release_date_y': 'release_date'}, inplace = True)

# %%
merged_df.columns
# Out:
# Index(['title', 'production_budget', 'domestic_gross', 'worldwide_gross',
#        'year', 'popularity', 'vote_count', 'original_language',
#        'original_title', 'genre_ids', 'vote_average', 'overview',
#        'release_date', 'action', 'adventure', 'animation', 'comedy', 'crime',
#        'documentary', 'drama', 'family', 'fantasy', 'history', 'horror',
#        'music', 'mystery', 'romance', 'science_fiction', 'tv_movie',
#        'thriller', 'war', 'western', 'worldwide_profit(loss)', 'roi', 'month',
#        'day'],
#       dtype='object')

# %% [markdown]
# Rearanging the columns makes the data easier to read.

# %%
cleaned_df = merged_df[['title','original_title', 'year', 'month', 'day', 'release_date', 'production_budget', 'domestic_gross', 'worldwide_gross', 
                           'worldwide_profit(loss)', 'roi', 'popularity', 'vote_count', 'vote_average', 'original_language', 'genre_ids',
        'action', 'adventure', 'animation', 'comedy', 'crime',
       'documentary', 'drama', 'family', 'fantasy', 'history', 'horror',
       'music', 'mystery', 'romance', 'science_fiction', 'tv_movie',
       'thriller', 'war', 'western', 'overview']]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4161 entries, 0 to 4365
# Data columns (total 36 columns):
# title                     4161 non-null object
# original_title            4161 non-null object
# year                      4161 non-null int64
# month                     4161 non-null int64
# day                       4161 non-null int64
# release_date              4161 non-null object
# production_budget         4161 non-null int64
# domestic_gross            4161 non-null int64
# worldwide_gross           4161 non-null int64
# worldwide_profit(loss)    4161 non-null int64
# roi                       4161 non-null float64
# popularity                4161 non-null float64
# vote_count                4161 non-null int64
# vote_average              4161 non-null float64
# original_language         4161 non-null object
# genre_ids                 4161 non-null object
# action                    4161 non-null bool
# adventure                 4161 non-null bool
# animation                 4161 non-null bool
# comedy                    4161 non-null bool
# crime                     4161 non-null bool
# documentary               4161 non-null bool
# drama                     4161 non-null bool
# family                    4161 non-null bool
# fantasy                   4161 non-null bool
# history                   4161 non-null bool
# horror                    4161 non-null bool
# music                     4161 non-null bool
# mystery                   4161 non-null bool
# romance                   4161 non-null bool
# science_fiction           4161 non-null bool
# tv_movie                  4161 non-null bool
# thriller                  4161 non-null bool
# war                       4161 non-null bool
# western                   4161 non-null bool
# overview                  4161 non-null object
# dtypes: bool(19), float64(3), int64(8), object(6)
# memory usage: 662.3+ KB

# %%
cleaned_df
# Out:
#                                             title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 4353                        In the Company of Men
# 4354                                       Exeter
# 4356                                      Slacker
# 4364                                       Primer
# 4365                                    Following
#
#                                    original_title  year  month  day  \
# 0                                          Avatar  2009     12   10
# 1     Pirates of the Caribbean: On Stranger Tides  2011      5   14
# 2                                    Dark Phoenix  2019      6    5
# 3                         Avengers: Age of Ultron  2015      4   22
# 4                          Avengers: Infinity War  2018      4   25
# ...                                           ...   ...    ...  ...
# 4353                        In the Company of Men  1997      3   28
# 4354                                       Exeter  2015      1   16
# 4356                                      Slacker  1991      7    5
# 4364                                       Primer  2004     10    8
# 4365                                    Following  1999      4    2
#
#      release_date  production_budget  domestic_gross  worldwide_gross  \
# 0      2009-12-10          425000000       760507625       2776345279
# 1      2011-05-14          410600000       241063875       1045663875
# 2      2019-06-05          350000000        42762350        149762350
# 3      2015-04-22          330600000       459005868       1403013963
# 4      2018-04-25          300000000       678815482       2048134200
# ...           ...                ...             ...              ...
# 4353   1997-03-28              25000         2883661          2883661
# 4354   2015-01-16              25000               0           489792
# 4356   1991-07-05              23000         1227508          1227508
# 4364   2004-10-08               7000          424760           841926
# 4365   1999-04-02               6000           48482           240495
#
#       worldwide_profit(loss)  ...  horror  music  mystery  romance  \
# 0                 2351345279  ...   False  False    False    False
# 1                  635063875  ...   False  False    False    False
# 2                 -200237650  ...   False  False    False    False
# 3                 1072413963  ...   False  False    False    False
# 4                 1748134200  ...   False  False    False    False
# ...                      ...  ...     ...    ...      ...      ...
# 4353                 2858661  ...   False  False    False    False
# 4354                  464792  ...    True  False    False    False
# 4356                 1204508  ...   False  False    False    False
# 4364                  834926  ...   False  False    False    False
# 4365                  234495  ...   False  False    False    False
#
#      science_fiction tv_movie  thriller    war  western  \
# 0               True    False     False  False    False
# 1              False    False     False  False    False
# 2               True    False     False  False    False
# 3               True    False     False  False    False
# 4               True    False     False  False    False
# ...              ...      ...       ...    ...      ...
# 4353           False    False     False  False    False
# 4354           False    False      True  False    False
# 4356           False    False     False  False    False
# 4364            True    False      True  False    False
# 4365           False    False      True  False    False
#
#                                                overview
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Jack Sparrow crosses paths with a woma...
# 2     The X-Men face their most formidable and power...
# 3     When Tony Stark tries to jumpstart a dormant p...
# 4     As the Avengers and their allies have continue...
# ...                                                 ...
# 4353  Two business executives--one an avowed misogyn...
# 4354  During an all-night, drug-fueled party at an a...
# 4356  Austin, Texas, is an Eden for the young and un...
# 4364  Friends and fledgling entrepreneurs invent a d...
# 4365  Bill, an idle, unemployed aspiring writer, wal...
#
# [4161 rows x 36 columns]

# %% [markdown]
# Saving the cleaned and merged dataframe to a csv file.

# %%
cleaned_df.to_csv('Data/cleaned_data.csv', index=False)
